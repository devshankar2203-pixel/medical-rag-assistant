# %% [markdown]
# <a href="https://colab.research.google.com/github/devshankar2203-pixel/medical-rag-assistant/blob/main/Healthcare_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-community langchain-groq langchain-google-genai chromadb pypdf

# %%
# !pip show langchain langchain-community langchain-groq langchain-google-genai chromadb pypdf
# Out:
# Name: langchain
# Version: 1.3.11
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# ---
# Name: langchain-community
# Version: 0.4.2
# Summary: Community contributed LangChain integrations.
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: aiohttp, httpx-sse, langchain-classic, langchain-core, langsmith, numpy, pydantic-settings, pyyaml, requests, sqlalchemy, tenacity
# Required-by:
# ---
# Name: langchain-groq
# Version: 1.1.3
# Summary: An integration package connecting Groq and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/groq
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# ...

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
os.environ["GEMINI_API_KEY"]="Geminiapi"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.3,
    max_tokens=200 # Reduced max_tokens for a more concise response
)

# %%
from google.colab import userdata
GEMINI_API_KEY = userdata.get('Geminiapi')
GROQ_API_KEY = userdata.get('Groqapi')
kaggle_api_key = userdata.get('kaggle')

# %%
from langchain_groq import ChatGroq
from google.colab import userdata
from langchain_groq import ChatGroq

# Load API key
GROQ_API_KEY = userdata.get('Groqapi')
llm = ChatGroq(
    model="openai/gpt-oss-20b",
    api_key=GROQ_API_KEY,
    temperature=0.3,
    max_tokens=1000 # Increased max_tokens for a more complete response
)

# %%
pip install duckduckgo-search

# %%
pip install langchain-community

# %%
# Query 1
query = "What should i take for high blood pressure"
response =({"query": query})

# %%
llm_response = llm.invoke(query)
print(llm_response.content)
# Out:
# I’m not a medical professional, so I can’t give you a prescription or specific medication recommendation. However, I can share some general information that many people find helpful when managing high blood pressure (hypertension). It’s always best to discuss any treatment plan with a qualified healthcare provider who can tailor advice to your personal health needs.
#
# ---
#
# ## 1. Lifestyle Changes That Often Help
#
# | Area | Typical Recommendations | Why It Helps |
# |------|--------------------------|--------------|
# | **Diet** | • Reduce sodium (salt) intake to < 2 g/day (≈ 5 g of salt).<br>• Increase fruits, vegetables, whole grains, and low‑fat dairy.<br>• Follow DASH (Dietary Approaches to Stop Hypertension) or Mediterranean diet. | Lower sodium reduces fluid retention; potassium‑rich foods help balance sodium. |
# ...

# %%
llm_response = llm.invoke(query)
print(llm_response.content)
# Out:
# I’m not a medical professional, so I can’t give you a prescription or specific treatment plan. However, I can share some general information that many people find helpful when managing high blood pressure (hypertension). It’s always best to discuss any changes with your doctor or another qualified healthcare provider.
#
# ---
#
# ## 1. Lifestyle Changes That Often Help
#
# | Change | Why It Helps | Practical Tips |
# |--------|--------------|----------------|
# | **Healthy diet** | Reduces sodium, increases potassium, and supports heart health. | • Follow the DASH diet (high in fruits, veggies, whole grains, lean protein). <br>• Limit processed foods, salty snacks, and sugary drinks. <br>• Aim for < 2,300 mg of sodium per day (many people can do even less). |
# ...

# %%
# Query 1
query = "i have severe headache what should i do"
response =({"query": query})

# %%
llm_response = llm.invoke(query)
print(llm_response.content)
# Out:
# I’m sorry you’re feeling so uncomfortable. While I’m not a medical professional, here are some general steps you can consider:
#
# 1. **Rest in a quiet, dark room**
#    - Bright lights, loud noises, or strong smells can sometimes worsen a headache.
#    - Try to lie down and relax for a bit.
#
# 2. **Hydrate**
#    - Dehydration can trigger or intensify headaches.
#    - Sip water, herbal tea, or an electrolyte drink slowly.
#
# 3. **Over‑the‑counter pain relief**
#    - Acetaminophen (Tylenol) or ibuprofen (Advil, Motrin) can help, but follow the dosing instructions on the label.
#    - Avoid exceeding the maximum daily dose and be mindful of any other medications you’re taking.
#
# 4. **Apply a cold or warm compress**
#    - Some people find relief with a cold pack on the forehead or a warm compress on the neck/shoulders.
#    - Experiment to see what feels better for you.
#
# 5. **Gentle stretching or light movement**
# ...
